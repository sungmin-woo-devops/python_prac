# %% [markdown]
# Colab의 Github 연동 코드(출처: https://gksdudrb922.tistory.com/208)

# %%
# 구글 드라이브
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# github와 연동하고 싶은 폴더로 이동
# %cd '/content/gdrive/MyDrive/Colab Notebooks'
# Out:
# /content/gdrive/MyDrive/Colab Notebooks

# %%
# git 생성
# !git init
# !git config --global user.email "sungminwoo.devops@gmail.com"
# !git config --global use"sungmin-woo-devops"
# Out:
# Reinitialized existing Git repository in /content/gdrive/MyDrive/Colab Notebooks/.git/
# error: key does not contain a section: usesungmin-woo-devops

# %%
# git commit
# !git add .
# !git command -m "first commit"

# %%
# github
# !git remote add origin https://colab_github_python@github.com/sungmin-woo-devops/python_prac.git
